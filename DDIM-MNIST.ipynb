# %% [markdown]
# <a href="https://colab.research.google.com/github/lb-97/GenerativeAI-DDIM-MNIST/blob/main/DDIM-MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
from PIL import Image

import tensorflow as tf
from tensorflow import keras, einsum
from tensorflow.keras import Model, Sequential
from tensorflow.keras import layers
# import tensorflow.keras.layers as nn
# import tensorflow_addons as tfa
# import tensorflow_datasets as tfds

# from einops import rearrange
# from einops.layers.tensorflow import Rearrange
# from functools import partial
# from inspect import isfunction

# %%
timesteps = 200

# create a fixed beta schedule
beta = np.linspace(0.0001, 0.02, timesteps)

# this will be used as discussed in the reparameterization trick
alpha = 1 - beta
alpha_bar = np.cumprod(alpha, 0)
# alpha_bar = np.concatenate((np.array([1.]), alpha_bar[:-1]), axis=0)
sqrt_alpha_bar = np.sqrt(alpha_bar)
sqrt_one_minus_alpha_bar = np.sqrt(1-alpha_bar)

alpha = tf.constant(alpha)
alpha_bar = tf.constant(alpha_bar)
sqrt_alpha_bar = tf.constant(sqrt_alpha_bar,dtype=tf.float32)
sqrt_one_minus_alpha_bar = tf.constant(sqrt_one_minus_alpha_bar,dtype=tf.float32)

# %%
(sqrt_alpha_bar.dtype)
# Out:
# tf.float32

# %%
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )

class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj

class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply

# %%
first_conv_channels=64
def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(img_size, img_size, img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, temb]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
      for _ in range(num_res_blocks + 1):
        #print(x.shape, skips[-1].shape)
        x = layers.Concatenate(axis=-1)([x, skips.pop()])
        x = ResidualBlock(
            widths[i], groups=norm_groups, activation_fn=activation_fn
        )([x, temb])
        if has_attention[i]:
            x = AttentionBlock(widths[i], groups=norm_groups)(x)

      if i != 0:
        x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(1, (3, 3), padding="same", kernel_initializer=kernel_init(0.0))(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
build_model(img_size=8,
        img_channels=16,
        widths=[64,128,256],
        has_attention=[False, False, True, True]).summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  time_input (InputLayer)        [(None,)]            0           []
#
#  time_embedding_16 (TimeEmbeddi  (None, 256)         0           ['time_input[0][0]']
#  ng)
#
#  image_input (InputLayer)       [(None, 8, 8, 16)]   0           []
#
#  dense_370 (Dense)              (None, 256)          65792       ['time_embedding_16[0][0]']
#
#  conv2d_501 (Conv2D)            (None, 8, 8, 64)     9280        ['image_input[0][0]']
#
#  dense_371 (Dense)              (None, 256)          65792       ['dense_370[0][0]']
#
#  group_normalization_399 (Group  (None, 8, 8, 64)    128         ['conv2d_501[0][0]']
#  Normalization)
#
#  tf.nn.silu_532 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_533 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_399[0][0]']
#
#  dense_372 (Dense)              (None, 64)           16448       ['tf.nn.silu_532[0][0]']
#
#  conv2d_502 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_533[0][0]']
#
#  tf.__operators__.getitem_174 (  (None, 1, 1, 64)    0           ['dense_372[0][0]']
#  SlicingOpLambda)
#
#  add_348 (Add)                  (None, 8, 8, 64)     0           ['conv2d_502[0][0]',
#                                                                   'tf.__operators__.getitem_174[0]
#                                                                  [0]']
#
#  group_normalization_400 (Group  (None, 8, 8, 64)    128         ['add_348[0][0]']
#  Normalization)
#
#  tf.nn.silu_534 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_400[0][0]']
#
#  conv2d_503 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_534[0][0]']
#
#  add_349 (Add)                  (None, 8, 8, 64)     0           ['conv2d_503[0][0]',
#                                                                   'conv2d_501[0][0]']
#
#  group_normalization_401 (Group  (None, 8, 8, 64)    128         ['add_349[0][0]']
#  Normalization)
#
#  tf.nn.silu_535 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_536 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_401[0][0]']
#
#  dense_373 (Dense)              (None, 64)           16448       ['tf.nn.silu_535[0][0]']
#
#  conv2d_504 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_536[0][0]']
#
#  tf.__operators__.getitem_175 (  (None, 1, 1, 64)    0           ['dense_373[0][0]']
#  SlicingOpLambda)
#
#  add_350 (Add)                  (None, 8, 8, 64)     0           ['conv2d_504[0][0]',
#                                                                   'tf.__operators__.getitem_175[0]
#                                                                  [0]']
#
#  group_normalization_402 (Group  (None, 8, 8, 64)    128         ['add_350[0][0]']
#  Normalization)
#
#  tf.nn.silu_537 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_402[0][0]']
#
#  conv2d_505 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_537[0][0]']
#
#  add_351 (Add)                  (None, 8, 8, 64)     0           ['conv2d_505[0][0]',
#                                                                   'add_349[0][0]']
#
#  conv2d_506 (Conv2D)            (None, 4, 4, 64)     36928       ['add_351[0][0]']
#
#  group_normalization_403 (Group  (None, 4, 4, 64)    128         ['conv2d_506[0][0]']
#  Normalization)
#
#  tf.nn.silu_538 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_539 (TFOpLambda)    (None, 4, 4, 64)     0           ['group_normalization_403[0][0]']
#
#  dense_374 (Dense)              (None, 128)          32896       ['tf.nn.silu_538[0][0]']
#
#  conv2d_508 (Conv2D)            (None, 4, 4, 128)    73856       ['tf.nn.silu_539[0][0]']
#
#  tf.__operators__.getitem_176 (  (None, 1, 1, 128)   0           ['dense_374[0][0]']
#  SlicingOpLambda)
#
#  add_352 (Add)                  (None, 4, 4, 128)    0           ['conv2d_508[0][0]',
#                                                                   'tf.__operators__.getitem_176[0]
#                                                                  [0]']
#
#  group_normalization_404 (Group  (None, 4, 4, 128)   256         ['add_352[0][0]']
#  Normalization)
#
#  tf.nn.silu_540 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_404[0][0]']
#
#  conv2d_509 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_540[0][0]']
#
#  conv2d_507 (Conv2D)            (None, 4, 4, 128)    8320        ['conv2d_506[0][0]']
#
#  add_353 (Add)                  (None, 4, 4, 128)    0           ['conv2d_509[0][0]',
#                                                                   'conv2d_507[0][0]']
#
#  group_normalization_405 (Group  (None, 4, 4, 128)   256         ['add_353[0][0]']
#  Normalization)
#
#  tf.nn.silu_541 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_542 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_405[0][0]']
#
#  dense_375 (Dense)              (None, 128)          32896       ['tf.nn.silu_541[0][0]']
#
#  conv2d_510 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_542[0][0]']
#
#  tf.__operators__.getitem_177 (  (None, 1, 1, 128)   0           ['dense_375[0][0]']
#  SlicingOpLambda)
#
#  add_354 (Add)                  (None, 4, 4, 128)    0           ['conv2d_510[0][0]',
#                                                                   'tf.__operators__.getitem_177[0]
#                                                                  [0]']
#
#  group_normalization_406 (Group  (None, 4, 4, 128)   256         ['add_354[0][0]']
#  Normalization)
#
#  tf.nn.silu_543 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_406[0][0]']
#
#  conv2d_511 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_543[0][0]']
#
#  add_355 (Add)                  (None, 4, 4, 128)    0           ['conv2d_511[0][0]',
#                                                                   'add_353[0][0]']
#
#  conv2d_512 (Conv2D)            (None, 2, 2, 128)    147584      ['add_355[0][0]']
#
#  group_normalization_407 (Group  (None, 2, 2, 128)   256         ['conv2d_512[0][0]']
#  Normalization)
#
#  tf.nn.silu_544 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_545 (TFOpLambda)    (None, 2, 2, 128)    0           ['group_normalization_407[0][0]']
#
#  dense_376 (Dense)              (None, 256)          65792       ['tf.nn.silu_544[0][0]']
#
#  conv2d_514 (Conv2D)            (None, 2, 2, 256)    295168      ['tf.nn.silu_545[0][0]']
#
#  tf.__operators__.getitem_178 (  (None, 1, 1, 256)   0           ['dense_376[0][0]']
#  SlicingOpLambda)
#
#  add_356 (Add)                  (None, 2, 2, 256)    0           ['conv2d_514[0][0]',
#                                                                   'tf.__operators__.getitem_178[0]
#                                                                  [0]']
#
#  group_normalization_408 (Group  (None, 2, 2, 256)   512         ['add_356[0][0]']
#  Normalization)
#
#  tf.nn.silu_546 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_408[0][0]']
#
#  conv2d_515 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_546[0][0]']
#
#  conv2d_513 (Conv2D)            (None, 2, 2, 256)    33024       ['conv2d_512[0][0]']
#
#  add_357 (Add)                  (None, 2, 2, 256)    0           ['conv2d_515[0][0]',
#                                                                   'conv2d_513[0][0]']
#
#  attention_block_41 (AttentionB  (None, 2, 2, 256)   263680      ['add_357[0][0]']
#  lock)
#
#  group_normalization_410 (Group  (None, 2, 2, 256)   512         ['attention_block_41[0][0]']
#  Normalization)
#
#  tf.nn.silu_547 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_548 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_410[0][0]']
#
#  dense_381 (Dense)              (None, 256)          65792       ['tf.nn.silu_547[0][0]']
#
#  conv2d_516 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_548[0][0]']
#
#  tf.__operators__.getitem_179 (  (None, 1, 1, 256)   0           ['dense_381[0][0]']
#  SlicingOpLambda)
#
#  add_358 (Add)                  (None, 2, 2, 256)    0           ['conv2d_516[0][0]',
#                                                                   'tf.__operators__.getitem_179[0]
#                                                                  [0]']
#
#  group_normalization_411 (Group  (None, 2, 2, 256)   512         ['add_358[0][0]']
#  Normalization)
#
#  tf.nn.silu_549 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_411[0][0]']
#
#  conv2d_517 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_549[0][0]']
#
#  add_359 (Add)                  (None, 2, 2, 256)    0           ['conv2d_517[0][0]',
#                                                                   'attention_block_41[0][0]']
#
#  attention_block_42 (AttentionB  (None, 2, 2, 256)   263680      ['add_359[0][0]']
#  lock)
#
#  group_normalization_413 (Group  (None, 2, 2, 256)   512         ['attention_block_42[0][0]']
#  Normalization)
#
#  tf.nn.silu_550 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_551 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_413[0][0]']
#
#  dense_386 (Dense)              (None, 256)          65792       ['tf.nn.silu_550[0][0]']
#
#  conv2d_518 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_551[0][0]']
#
#  tf.__operators__.getitem_180 (  (None, 1, 1, 256)   0           ['dense_386[0][0]']
#  SlicingOpLambda)
#
#  add_360 (Add)                  (None, 2, 2, 256)    0           ['conv2d_518[0][0]',
#                                                                   'tf.__operators__.getitem_180[0]
#                                                                  [0]']
#
#  group_normalization_414 (Group  (None, 2, 2, 256)   512         ['add_360[0][0]']
#  Normalization)
#
#  tf.nn.silu_552 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_414[0][0]']
#
#  conv2d_519 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_552[0][0]']
#
#  add_361 (Add)                  (None, 2, 2, 256)    0           ['conv2d_519[0][0]',
#                                                                   'attention_block_42[0][0]']
#
#  attention_block_43 (AttentionB  (None, 2, 2, 256)   263680      ['add_361[0][0]']
#  lock)
#
#  group_normalization_416 (Group  (None, 2, 2, 256)   512         ['attention_block_43[0][0]']
#  Normalization)
#
#  tf.nn.silu_553 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_554 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_416[0][0]']
#
#  dense_391 (Dense)              (None, 256)          65792       ['tf.nn.silu_553[0][0]']
#
#  conv2d_520 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_554[0][0]']
#
#  tf.__operators__.getitem_181 (  (None, 1, 1, 256)   0           ['dense_391[0][0]']
#  SlicingOpLambda)
#
#  add_362 (Add)                  (None, 2, 2, 256)    0           ['conv2d_520[0][0]',
#                                                                   'tf.__operators__.getitem_181[0]
#                                                                  [0]']
#
#  group_normalization_417 (Group  (None, 2, 2, 256)   512         ['add_362[0][0]']
#  Normalization)
#
#  tf.nn.silu_555 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_417[0][0]']
#
#  conv2d_521 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_555[0][0]']
#
#  add_363 (Add)                  (None, 2, 2, 256)    0           ['conv2d_521[0][0]',
#                                                                   'attention_block_43[0][0]']
#
#  concatenate_84 (Concatenate)   (None, 2, 2, 512)    0           ['add_363[0][0]',
#                                                                   'attention_block_42[0][0]']
#
#  group_normalization_418 (Group  (None, 2, 2, 512)   1024        ['concatenate_84[0][0]']
#  Normalization)
#
#  tf.nn.silu_556 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_557 (TFOpLambda)    (None, 2, 2, 512)    0           ['group_normalization_418[0][0]']
#
#  dense_392 (Dense)              (None, 256)          65792       ['tf.nn.silu_556[0][0]']
#
#  conv2d_523 (Conv2D)            (None, 2, 2, 256)    1179904     ['tf.nn.silu_557[0][0]']
#
#  tf.__operators__.getitem_182 (  (None, 1, 1, 256)   0           ['dense_392[0][0]']
#  SlicingOpLambda)
#
#  add_364 (Add)                  (None, 2, 2, 256)    0           ['conv2d_523[0][0]',
#                                                                   'tf.__operators__.getitem_182[0]
#                                                                  [0]']
#
#  group_normalization_419 (Group  (None, 2, 2, 256)   512         ['add_364[0][0]']
#  Normalization)
#
#  tf.nn.silu_558 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_419[0][0]']
#
#  conv2d_524 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_558[0][0]']
#
#  conv2d_522 (Conv2D)            (None, 2, 2, 256)    131328      ['concatenate_84[0][0]']
#
#  add_365 (Add)                  (None, 2, 2, 256)    0           ['conv2d_524[0][0]',
#                                                                   'conv2d_522[0][0]']
#
#  attention_block_44 (AttentionB  (None, 2, 2, 256)   263680      ['add_365[0][0]']
#  lock)
#
#  concatenate_85 (Concatenate)   (None, 2, 2, 512)    0           ['attention_block_44[0][0]',
#                                                                   'attention_block_41[0][0]']
#
#  group_normalization_421 (Group  (None, 2, 2, 512)   1024        ['concatenate_85[0][0]']
#  Normalization)
#
#  tf.nn.silu_559 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_560 (TFOpLambda)    (None, 2, 2, 512)    0           ['group_normalization_421[0][0]']
#
#  dense_397 (Dense)              (None, 256)          65792       ['tf.nn.silu_559[0][0]']
#
#  conv2d_526 (Conv2D)            (None, 2, 2, 256)    1179904     ['tf.nn.silu_560[0][0]']
#
#  tf.__operators__.getitem_183 (  (None, 1, 1, 256)   0           ['dense_397[0][0]']
#  SlicingOpLambda)
#
#  add_366 (Add)                  (None, 2, 2, 256)    0           ['conv2d_526[0][0]',
#                                                                   'tf.__operators__.getitem_183[0]
#                                                                  [0]']
#
#  group_normalization_422 (Group  (None, 2, 2, 256)   512         ['add_366[0][0]']
#  Normalization)
#
#  tf.nn.silu_561 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_422[0][0]']
#
#  conv2d_527 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_561[0][0]']
#
#  conv2d_525 (Conv2D)            (None, 2, 2, 256)    131328      ['concatenate_85[0][0]']
#
#  add_367 (Add)                  (None, 2, 2, 256)    0           ['conv2d_527[0][0]',
#                                                                   'conv2d_525[0][0]']
#
#  attention_block_45 (AttentionB  (None, 2, 2, 256)   263680      ['add_367[0][0]']
#  lock)
#
#  concatenate_86 (Concatenate)   (None, 2, 2, 384)    0           ['attention_block_45[0][0]',
#                                                                   'conv2d_512[0][0]']
#
#  group_normalization_424 (Group  (None, 2, 2, 384)   768         ['concatenate_86[0][0]']
#  Normalization)
#
#  tf.nn.silu_562 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_563 (TFOpLambda)    (None, 2, 2, 384)    0           ['group_normalization_424[0][0]']
#
#  dense_402 (Dense)              (None, 256)          65792       ['tf.nn.silu_562[0][0]']
#
#  conv2d_529 (Conv2D)            (None, 2, 2, 256)    884992      ['tf.nn.silu_563[0][0]']
#
#  tf.__operators__.getitem_184 (  (None, 1, 1, 256)   0           ['dense_402[0][0]']
#  SlicingOpLambda)
#
#  add_368 (Add)                  (None, 2, 2, 256)    0           ['conv2d_529[0][0]',
#                                                                   'tf.__operators__.getitem_184[0]
#                                                                  [0]']
#
#  group_normalization_425 (Group  (None, 2, 2, 256)   512         ['add_368[0][0]']
#  Normalization)
#
#  tf.nn.silu_564 (TFOpLambda)    (None, 2, 2, 256)    0           ['group_normalization_425[0][0]']
#
#  conv2d_530 (Conv2D)            (None, 2, 2, 256)    590080      ['tf.nn.silu_564[0][0]']
#
#  conv2d_528 (Conv2D)            (None, 2, 2, 256)    98560       ['concatenate_86[0][0]']
#
#  add_369 (Add)                  (None, 2, 2, 256)    0           ['conv2d_530[0][0]',
#                                                                   'conv2d_528[0][0]']
#
#  attention_block_46 (AttentionB  (None, 2, 2, 256)   263680      ['add_369[0][0]']
#  lock)
#
#  up_sampling2d_16 (UpSampling2D  (None, 4, 4, 256)   0           ['attention_block_46[0][0]']
#  )
#
#  conv2d_531 (Conv2D)            (None, 4, 4, 256)    590080      ['up_sampling2d_16[0][0]']
#
#  concatenate_87 (Concatenate)   (None, 4, 4, 384)    0           ['conv2d_531[0][0]',
#                                                                   'add_355[0][0]']
#
#  group_normalization_427 (Group  (None, 4, 4, 384)   768         ['concatenate_87[0][0]']
#  Normalization)
#
#  tf.nn.silu_565 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_566 (TFOpLambda)    (None, 4, 4, 384)    0           ['group_normalization_427[0][0]']
#
#  dense_407 (Dense)              (None, 128)          32896       ['tf.nn.silu_565[0][0]']
#
#  conv2d_533 (Conv2D)            (None, 4, 4, 128)    442496      ['tf.nn.silu_566[0][0]']
#
#  tf.__operators__.getitem_185 (  (None, 1, 1, 128)   0           ['dense_407[0][0]']
#  SlicingOpLambda)
#
#  add_370 (Add)                  (None, 4, 4, 128)    0           ['conv2d_533[0][0]',
#                                                                   'tf.__operators__.getitem_185[0]
#                                                                  [0]']
#
#  group_normalization_428 (Group  (None, 4, 4, 128)   256         ['add_370[0][0]']
#  Normalization)
#
#  tf.nn.silu_567 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_428[0][0]']
#
#  conv2d_534 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_567[0][0]']
#
#  conv2d_532 (Conv2D)            (None, 4, 4, 128)    49280       ['concatenate_87[0][0]']
#
#  add_371 (Add)                  (None, 4, 4, 128)    0           ['conv2d_534[0][0]',
#                                                                   'conv2d_532[0][0]']
#
#  concatenate_88 (Concatenate)   (None, 4, 4, 256)    0           ['add_371[0][0]',
#                                                                   'add_353[0][0]']
#
#  group_normalization_429 (Group  (None, 4, 4, 256)   512         ['concatenate_88[0][0]']
#  Normalization)
#
#  tf.nn.silu_568 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_569 (TFOpLambda)    (None, 4, 4, 256)    0           ['group_normalization_429[0][0]']
#
#  dense_408 (Dense)              (None, 128)          32896       ['tf.nn.silu_568[0][0]']
#
#  conv2d_536 (Conv2D)            (None, 4, 4, 128)    295040      ['tf.nn.silu_569[0][0]']
#
#  tf.__operators__.getitem_186 (  (None, 1, 1, 128)   0           ['dense_408[0][0]']
#  SlicingOpLambda)
#
#  add_372 (Add)                  (None, 4, 4, 128)    0           ['conv2d_536[0][0]',
#                                                                   'tf.__operators__.getitem_186[0]
#                                                                  [0]']
#
#  group_normalization_430 (Group  (None, 4, 4, 128)   256         ['add_372[0][0]']
#  Normalization)
#
#  tf.nn.silu_570 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_430[0][0]']
#
#  conv2d_537 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_570[0][0]']
#
#  conv2d_535 (Conv2D)            (None, 4, 4, 128)    32896       ['concatenate_88[0][0]']
#
#  add_373 (Add)                  (None, 4, 4, 128)    0           ['conv2d_537[0][0]',
#                                                                   'conv2d_535[0][0]']
#
#  concatenate_89 (Concatenate)   (None, 4, 4, 192)    0           ['add_373[0][0]',
#                                                                   'conv2d_506[0][0]']
#
#  group_normalization_431 (Group  (None, 4, 4, 192)   384         ['concatenate_89[0][0]']
#  Normalization)
#
#  tf.nn.silu_571 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_572 (TFOpLambda)    (None, 4, 4, 192)    0           ['group_normalization_431[0][0]']
#
#  dense_409 (Dense)              (None, 128)          32896       ['tf.nn.silu_571[0][0]']
#
#  conv2d_539 (Conv2D)            (None, 4, 4, 128)    221312      ['tf.nn.silu_572[0][0]']
#
#  tf.__operators__.getitem_187 (  (None, 1, 1, 128)   0           ['dense_409[0][0]']
#  SlicingOpLambda)
#
#  add_374 (Add)                  (None, 4, 4, 128)    0           ['conv2d_539[0][0]',
#                                                                   'tf.__operators__.getitem_187[0]
#                                                                  [0]']
#
#  group_normalization_432 (Group  (None, 4, 4, 128)   256         ['add_374[0][0]']
#  Normalization)
#
#  tf.nn.silu_573 (TFOpLambda)    (None, 4, 4, 128)    0           ['group_normalization_432[0][0]']
#
#  conv2d_540 (Conv2D)            (None, 4, 4, 128)    147584      ['tf.nn.silu_573[0][0]']
#
#  conv2d_538 (Conv2D)            (None, 4, 4, 128)    24704       ['concatenate_89[0][0]']
#
#  add_375 (Add)                  (None, 4, 4, 128)    0           ['conv2d_540[0][0]',
#                                                                   'conv2d_538[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 8, 8, 128)   0           ['add_375[0][0]']
#  )
#
#  conv2d_541 (Conv2D)            (None, 8, 8, 128)    147584      ['up_sampling2d_17[0][0]']
#
#  concatenate_90 (Concatenate)   (None, 8, 8, 192)    0           ['conv2d_541[0][0]',
#                                                                   'add_351[0][0]']
#
#  group_normalization_433 (Group  (None, 8, 8, 192)   384         ['concatenate_90[0][0]']
#  Normalization)
#
#  tf.nn.silu_574 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_575 (TFOpLambda)    (None, 8, 8, 192)    0           ['group_normalization_433[0][0]']
#
#  dense_410 (Dense)              (None, 64)           16448       ['tf.nn.silu_574[0][0]']
#
#  conv2d_543 (Conv2D)            (None, 8, 8, 64)     110656      ['tf.nn.silu_575[0][0]']
#
#  tf.__operators__.getitem_188 (  (None, 1, 1, 64)    0           ['dense_410[0][0]']
#  SlicingOpLambda)
#
#  add_376 (Add)                  (None, 8, 8, 64)     0           ['conv2d_543[0][0]',
#                                                                   'tf.__operators__.getitem_188[0]
#                                                                  [0]']
#
#  group_normalization_434 (Group  (None, 8, 8, 64)    128         ['add_376[0][0]']
#  Normalization)
#
#  tf.nn.silu_576 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_434[0][0]']
#
#  conv2d_544 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_576[0][0]']
#
#  conv2d_542 (Conv2D)            (None, 8, 8, 64)     12352       ['concatenate_90[0][0]']
#
#  add_377 (Add)                  (None, 8, 8, 64)     0           ['conv2d_544[0][0]',
#                                                                   'conv2d_542[0][0]']
#
#  concatenate_91 (Concatenate)   (None, 8, 8, 128)    0           ['add_377[0][0]',
#                                                                   'add_349[0][0]']
#
#  group_normalization_435 (Group  (None, 8, 8, 128)   256         ['concatenate_91[0][0]']
#  Normalization)
#
#  tf.nn.silu_577 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_578 (TFOpLambda)    (None, 8, 8, 128)    0           ['group_normalization_435[0][0]']
#
#  dense_411 (Dense)              (None, 64)           16448       ['tf.nn.silu_577[0][0]']
#
#  conv2d_546 (Conv2D)            (None, 8, 8, 64)     73792       ['tf.nn.silu_578[0][0]']
#
#  tf.__operators__.getitem_189 (  (None, 1, 1, 64)    0           ['dense_411[0][0]']
#  SlicingOpLambda)
#
#  add_378 (Add)                  (None, 8, 8, 64)     0           ['conv2d_546[0][0]',
#                                                                   'tf.__operators__.getitem_189[0]
#                                                                  [0]']
#
#  group_normalization_436 (Group  (None, 8, 8, 64)    128         ['add_378[0][0]']
#  Normalization)
#
#  tf.nn.silu_579 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_436[0][0]']
#
#  conv2d_547 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_579[0][0]']
#
#  conv2d_545 (Conv2D)            (None, 8, 8, 64)     8256        ['concatenate_91[0][0]']
#
#  add_379 (Add)                  (None, 8, 8, 64)     0           ['conv2d_547[0][0]',
#                                                                   'conv2d_545[0][0]']
#
#  concatenate_92 (Concatenate)   (None, 8, 8, 128)    0           ['add_379[0][0]',
#                                                                   'conv2d_501[0][0]']
#
#  group_normalization_437 (Group  (None, 8, 8, 128)   256         ['concatenate_92[0][0]']
#  Normalization)
#
#  tf.nn.silu_580 (TFOpLambda)    (None, 256)          0           ['dense_371[0][0]']
#
#  tf.nn.silu_581 (TFOpLambda)    (None, 8, 8, 128)    0           ['group_normalization_437[0][0]']
#
#  dense_412 (Dense)              (None, 64)           16448       ['tf.nn.silu_580[0][0]']
#
#  conv2d_549 (Conv2D)            (None, 8, 8, 64)     73792       ['tf.nn.silu_581[0][0]']
#
#  tf.__operators__.getitem_190 (  (None, 1, 1, 64)    0           ['dense_412[0][0]']
#  SlicingOpLambda)
#
#  add_380 (Add)                  (None, 8, 8, 64)     0           ['conv2d_549[0][0]',
#                                                                   'tf.__operators__.getitem_190[0]
#                                                                  [0]']
#
#  group_normalization_438 (Group  (None, 8, 8, 64)    128         ['add_380[0][0]']
#  Normalization)
#
#  tf.nn.silu_582 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_438[0][0]']
#
#  conv2d_550 (Conv2D)            (None, 8, 8, 64)     36928       ['tf.nn.silu_582[0][0]']
#
#  conv2d_548 (Conv2D)            (None, 8, 8, 64)     8256        ['concatenate_92[0][0]']
#
#  add_381 (Add)                  (None, 8, 8, 64)     0           ['conv2d_550[0][0]',
#                                                                   'conv2d_548[0][0]']
#
#  group_normalization_439 (Group  (None, 8, 8, 64)    128         ['add_381[0][0]']
#  Normalization)
#
#  tf.nn.silu_583 (TFOpLambda)    (None, 8, 8, 64)     0           ['group_normalization_439[0][0]']
#
#  conv2d_551 (Conv2D)            (None, 8, 8, 1)      577         ['tf.nn.silu_583[0][0]']
#
# ==================================================================================================
# Total params: 15,780,417
# Trainable params: 15,780,417
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class DiffusionModel(keras.Model):

  def __init__(self):
    super().__init__()
    self.network = build_model(img_size=28,
        img_channels=1,
        widths=[64,128,256],
        has_attention=[False, False, True, True])
    self.timesteps=timesteps

  def extract(self, t):
    return

  def train_step(self,images):
    batch_size = images.shape[0]
    t = tf.random.uniform(
            minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64
        )
    with tf.GradientTape() as tape:
      # 3. Sample random noise to be added to the images in the batch
      noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)

      # 4. Diffuse the images with noise
      sqb = tf.reshape(tf.gather(sqrt_alpha_bar,t),[batch_size,1,1,1])
      osqb = tf.reshape(tf.gather(sqrt_one_minus_alpha_bar,t),[batch_size,1,1,1])
      noisy_img = sqb*images + osqb*noise
      #images_t = self.gdf_util.q_sample(images, t, noise)

      # 5. Pass the diffused images and time steps to the network
      pred_noise = self.network([noisy_img, t], training=True)

      # 6. Calculate the loss
      lo = self.loss(noise, pred_noise)

    gradients = tape.gradient(lo, self.network.trainable_weights)

    # 8. Update the weights of the network
    self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

    return {"loss": lo}

  def generate(self, shape):
    noisy_image = tf.random.normal(shape=shape, dtype=tf.float32)
    for i in range(timesteps-1,-1,-1):
      if i>0:
        noise = tf.random.normal(shape=shape, dtype=tf.float32)
      else:
        noise = 0

      pred_noise = self.network(noisy_image, i)

      a = tf.reshape(tf.gather(alpha,i),[shape[0],1,1,1])
      sqab = tf.reshape(tf.gather(sqrt_one_minus_alpha_bar,i),[shape[0],1,1,1])
      pred_noise = ((1-a)/sqab)*pred_noise

      noisy_image = (noisy_image-pred_noise)/tf.sqrt(a) + noise

    return noisy_image

# %%
(x_train, x_train_labels), (x_test, _) = keras.datasets.mnist.load_data()

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
x_train_scaled = (x_train / 255.0) - 0.5
x_test_scaled = (x_test / 255.0) - 0.5

data_variance = np.var(x_train / 255.0)

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4033244786859197162
#  xla_global_id: -1]

# %%
with tf.device('/device:GPU:0'):
    model = DiffusionModel()

    # Compile the model
    model.compile(
        loss=keras.losses.MeanSquaredError(),
        optimizer=keras.optimizers.Adam(learning_rate=0.0002),
    )

    # Train the model
    model.fit(
        x_train_scaled,
        epochs=10,
        batch_size=1
        #callbacks=[keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images)],
    )
